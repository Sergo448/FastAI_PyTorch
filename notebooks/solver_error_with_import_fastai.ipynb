# %%
# !pip uninstall fastai

# !pip install https://github.com/fastai/fastai1/archive/master.zip

# %%
# !pip install fastai --upgrade
# Out:
# Requirement already satisfied: fastai in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (1.0.64.dev0)
# Collecting fastai
#   Using cached fastai-2.7.10-py3-none-any.whl (240 kB)
# Requirement already satisfied: pandas in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.5.2)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: requests in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (2.28.1)
# Requirement already satisfied: packaging in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (22.0)
# Requirement already satisfied: pillow>6.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (9.4.0)
# Requirement already satisfied: matplotlib in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (3.6.2)
# Requirement already satisfied: scikit-learn in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.2.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: pyyaml in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (6.0)
# Requirement already satisfied: spacy<4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (3.4.4)
# Requirement already satisfied: torchvision>=0.8.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (0.14.1)
# Requirement already satisfied: pip in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (22.3.1)
# Requirement already satisfied: torch<1.14,>=1.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.13.1)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.5.27)
# Requirement already satisfied: scipy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.10.0)
# Requirement already satisfied: setuptools in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (65.6.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.24.1)
# Requirement already satisfied: jinja2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (4.64.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (6.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.10.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (2.1.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.7.99)
# Requirement already satisfied: wheel in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14,>=1.7->fastai) (0.38.4)
# Requirement already satisfied: cycler>=0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from pandas->fastai) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Installing collected packages: fastai
#   Attempting uninstall: fastai
#     Found existing installation: fastai 1.0.64.dev0
#     Uninstalling fastai-1.0.64.dev0:
#       Successfully uninstalled fastai-1.0.64.dev0
# Successfully installed fastai-2.7.10

# %%
# !pip install fastai==2.0.15
# !pip install fastai2==0.0.30
# !pip install fastcore==1.0.16.
# Out:
# Collecting fastai==2.0.15
#   Downloading fastai-2.0.15-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 1.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.5.2)
# Requirement already satisfied: requests in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (2.28.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.0.3)
# Requirement already satisfied: torch>=1.6.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.13.1)
# Requirement already satisfied: pillow in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (9.4.0)
# Requirement already satisfied: pyyaml in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (6.0)
# Requirement already satisfied: pip in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (22.3.1)
# Requirement already satisfied: fastcore>=1.0.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.5.27)
# Requirement already satisfied: spacy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (3.4.4)
# Requirement already satisfied: scikit-learn in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.2.0)
# Requirement already satisfied: packaging in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (22.0)
# Requirement already satisfied: matplotlib in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (3.6.2)
# Requirement already satisfied: torchvision>=0.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (0.14.1)
# Requirement already satisfied: scipy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai==2.0.15) (1.10.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai==2.0.15) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai==2.0.15) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai==2.0.15) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai==2.0.15) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai==2.0.15) (8.5.0.96)
# Requirement already satisfied: wheel in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->fastai==2.0.15) (0.38.4)
# Requirement already satisfied: setuptools in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->fastai==2.0.15) (65.6.3)
# Requirement already satisfied: numpy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torchvision>=0.7->fastai==2.0.15) (1.24.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai==2.0.15) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from pandas->fastai==2.0.15) (2022.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai==2.0.15) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai==2.0.15) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai==2.0.15) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai==2.0.15) (1.26.13)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai==2.0.15) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai==2.0.15) (1.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (2.0.7)
# Requirement already satisfied: jinja2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (2.4.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (1.10.4)
# Requirement already satisfied: pathy>=0.3.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (3.0.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai==2.0.15) (1.0.9)
# Requirement already satisfied: six>=1.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai==2.0.15) (1.16.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy->fastai==2.0.15) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy->fastai==2.0.15) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy->fastai==2.0.15) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from jinja2->spacy->fastai==2.0.15) (2.1.1)
# Installing collected packages: fastai
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.10
#     Uninstalling fastai-2.7.10:
#       Successfully uninstalled fastai-2.7.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastbook 0.0.29 requires fastai>=2.6, but you have fastai 2.0.15 which is incompatible.
# Successfully installed fastai-2.0.15
# Collecting fastai2==0.0.30
#   Downloading fastai2-0.0.30-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 722.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (22.0)
# Requirement already satisfied: fastcore>=0.1.34 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.5.27)
# Requirement already satisfied: pip in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (22.3.1)
# Requirement already satisfied: matplotlib in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (3.6.2)
# Requirement already satisfied: pandas in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.5.2)
# Requirement already satisfied: spacy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (3.4.4)
# Requirement already satisfied: torch>=1.6.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.13.1)
# Requirement already satisfied: requests in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (2.28.1)
# Requirement already satisfied: pillow in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (9.4.0)
# Requirement already satisfied: scikit-learn in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.2.0)
# Requirement already satisfied: scipy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.10.0)
# Requirement already satisfied: pyyaml in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (6.0)
# Requirement already satisfied: torchvision>=0.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (0.14.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai2==0.0.30) (1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai2==0.0.30) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai2==0.0.30) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai2==0.0.30) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai2==0.0.30) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch>=1.6.0->fastai2==0.0.30) (11.7.99)
# Requirement already satisfied: setuptools in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->fastai2==0.0.30) (65.6.3)
# Requirement already satisfied: wheel in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->fastai2==0.0.30) (0.38.4)
# Requirement already satisfied: numpy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torchvision>=0.7->fastai2==0.0.30) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai2==0.0.30) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from pandas->fastai2==0.0.30) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai2==0.0.30) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai2==0.0.30) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai2==0.0.30) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai2==0.0.30) (2022.12.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai2==0.0.30) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai2==0.0.30) (3.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (0.7.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (6.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (3.0.11)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (2.0.8)
# Requirement already satisfied: jinja2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (1.10.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy->fastai2==0.0.30) (0.10.1)
# Requirement already satisfied: six>=1.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai2==0.0.30) (1.16.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy->fastai2==0.0.30) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy->fastai2==0.0.30) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy->fastai2==0.0.30) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from jinja2->spacy->fastai2==0.0.30) (2.1.1)
# Installing collected packages: fastai2
# Successfully installed fastai2-0.0.30
# Collecting fastcore==1.0.16.
#   Downloading fastcore-1.0.16-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 136.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastcore==1.0.16.) (22.0)
# Requirement already satisfied: pip in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastcore==1.0.16.) (22.3.1)
# Installing collected packages: fastcore
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.5.27
#     Uninstalling fastcore-1.5.27:
#       Successfully uninstalled fastcore-1.5.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastdownload 0.0.7 requires fastcore>=1.3.26, but you have fastcore 1.0.16 which is incompatible.
# Successfully installed fastcore-1.0.16

# %%
# !pip install fastai2 --quiet

# %%
pip install fastai --upgrade



"""
This one helps me to solvw the problem with 
from fastai.vision.all import *

"""
# Out:
# Requirement already satisfied: fastai in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (2.0.15)
# Collecting fastai
#   Using cached fastai-2.7.10-py3-none-any.whl (240 kB)
# Requirement already satisfied: pip in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (22.3.1)
# Requirement already satisfied: torch<1.14,>=1.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.13.1)
# Requirement already satisfied: packaging in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (22.0)
# Requirement already satisfied: pandas in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.5.2)
# Requirement already satisfied: pyyaml in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (6.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: torchvision>=0.8.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (0.14.1)
# Requirement already satisfied: scikit-learn in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.2.0)
# Requirement already satisfied: spacy<4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (3.4.4)
# Requirement already satisfied: pillow>6.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (9.4.0)
# Collecting fastcore<1.6,>=1.4.5
#   Using cached fastcore-1.5.27-py3-none-any.whl (67 kB)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: matplotlib in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (3.6.2)
# Requirement already satisfied: requests in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (2.28.1)
# Requirement already satisfied: scipy in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from fastai) (1.10.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (8.1.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.4.5)
# Requirement already satisfied: numpy>=1.15.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.24.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.4)
# Requirement already satisfied: jinja2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.11)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.10.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: setuptools in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (65.6.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from spacy<4->fastai) (6.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from requests->fastai) (2.1.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from torch<1.14,>=1.7->fastai) (8.5.0.96)
# Requirement already satisfied: wheel in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14,>=1.7->fastai) (0.38.4)
# Requirement already satisfied: cycler>=0.10 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from matplotlib->fastai) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from pandas->fastai) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from scikit-learn->fastai) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sergey/PycharmProjects/FastAI_PyTorch/venv/lib/python3.10/site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Installing collected packages: fastcore, fastai
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.0.16
#     Uninstalling fastcore-1.0.16:
#       Successfully uninstalled fastcore-1.0.16
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.0.15
#     Uninstalling fastai-2.0.15:
#       Successfully uninstalled fastai-2.0.15
# Successfully installed fastai-2.7.10 fastcore-1.5.27
# Note: you may need to restart the kernel to use updated packages.
